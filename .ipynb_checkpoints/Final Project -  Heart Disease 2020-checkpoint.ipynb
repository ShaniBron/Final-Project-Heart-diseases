# %% [markdown]
# # Heart Disease Dataset
#    by Renato Dunaevits and Shani Bronshtein

# %% [markdown]
# # Import Liberies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from functions import *
from pipeline import *
from sklearn.pipeline import Pipeline


from sklearn.model_selection import train_test_split as split, GridSearchCV, RepeatedStratifiedKFold

from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from xgboost import XGBClassifier

import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# # The Data

# %%
heartdf=pd.read_csv('heart_2020_cleaned.csv')

# %% [markdown]
# source: https://www.kaggle.com/datasets/kamilpytlak/personal-key-indicators-of-heart-disease

# %% [markdown]
# # Features

# %% [markdown]
# Key:
#
# Target --> HeartDisease (yes/no) - Respondents that have ever reported having coronary heart disease (CHD) or myocardial infarction (MI)
#
# * BMI - Body Mass Index
# * Smoking - Have you smoked at least 100 cigarettes in your entire life? [Note: 5 packs = 100 cigarettes]
# * AlcoholDrinking - Heavy drinkers (adult men having more than 14 drinks per week and adult women having more than 7 drinks per week
# * Stroke - Ever told) you had a stroke?
# * PhysicalHealth - Now thinking about your physical health, which includes physical illness and injury, for how many days during the past 30 days was your physical health not good? (0-30 days)
# * MentalHealth - Thinking about your mental health, for how many days during the past 30 days was your mental health not good? (0-30 days)
# * DiffWalking - Do you have serious difficulty walking or climbing stairs?
# * Sex - male/female
# * AgeCategory - Fourteen-level age category
# * Race - Imputed race/ethnicity value
# * Diabetic - Ever told you had diabetes?
# * PhysicalActivity - Adults who reported doing physical activity or exercise during the past 30 days other than their regular job
# * GenHealth - Would you say that in general your health is...
# * SleepTime - On average, how many hours of sleep do you get in a 24-hour period?
# * Asthma - Ever told you had asthma?
# * KidneyDisease - Not including kidney stones, bladder infection or incontinence, were you ever told you had kidney disease?
# * SkinCancer - Ever told you had skin cancer?

# %% [markdown]
# # EDA

# %%
heartdf.shape
# Out:
# (319795, 18)

# %%
heartdf.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0          30.0          No  Female        55-59  White      Yes
# 1           0.0          No  Female  80 or older  White       No
# 2          30.0          No    Male        65-69  White      Yes
# 3           0.0          No  Female        75-79  White       No
# 4           0.0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good        5.0    Yes            No        Yes
# 1              Yes  Very good        7.0     No            No         No
# 2              Yes       Fair        8.0    Yes            No         No
# 3               No       Good        6.0     No            No        Yes
# 4              Yes  Very good        8.0     No            No         No

# %%
heartdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
#  15  Asthma            319795 non-null  object
#  16  KidneyDisease     319795 non-null  object
#  17  SkinCancer        319795 non-null  object
# dtypes: float64(4), object(14)
# memory usage: 43.9+ MB

# %% [markdown]
# Most of features are object. So probably we will have to do a label encoder at the end.

# %%
heartdf.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
heartdf.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %% [markdown]
# It doesn't have any Null value

# %%
heartdf.nunique()
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %% [markdown]
# Most of the feature has less then 6 unique values. Just one feature with a lot of unique values

# %%
heartdf.duplicated().sum()
# Out:
# 18078

# %% [markdown]
# The dataset has a lot of duplicate rows. It means that this duplicate rows won't add anything for the model so It will be better to drop them.
#
# We don't want to destroy the dataset source so we will make a copy.

# %%
heart_for_dup=heartdf.copy()

# %%
heart_for_dup.shape
# Out:
# (319795, 18)

# %%
#drop duplicates
heart_for_dup.drop_duplicates(inplace=True)

# %%
heart_for_dup.shape
# Out:
# (301717, 18)

# %% [markdown]
# We can see that we just drop all the duplicate rows.

# %%
#targe vs.non-targe

heart_for_dup.groupby(['HeartDisease']).size()
# Out:
# HeartDisease
# No     274456
# Yes     27261
# dtype: int64

# %%
create_pie_chart(heart_for_dup,'HeartDisease')

# %% [markdown]
# Our target it's not balanced between the two options so we must use some of the options of imbalance data during the model.

# %%
create_pie_chart(heart_for_dup,'Sex')

# %%
create_pie_chart(heart_for_dup,'Race')

# %%
heart_for_dup.groupby(['Race']).size().sort_values()
# Out:
# Race
# American Indian/Alaskan Native      5192
# Asian                               7993
# Other                              10891
# Black                              22810
# Hispanic                           27107
# White                             227724
# dtype: int64

# %%
heart_for_dup.groupby(['Smoking']).size().sort_values()
# Out:
# Smoking
# Yes    127405
# No     174312
# dtype: int64

# %%
#List of age group
order_age=['18-24','25-29','30-34','35-39','40-44','45-49','50-54','55-59','60-64','65-69','70-74','75-79','80 or older']

# %%
sns.countplot(data=heart_for_dup,y='AgeCategory',hue='Smoking',order=order_age)

plt.title('Histogram of AgeCategory by Sex')
plt.show()

# %%
heart_for_dup.groupby(['Sex','HeartDisease'])['HeartDisease'].count()
# Out:
# Sex     HeartDisease
# Female  No              148458
#         Yes              11213
# Male    No              125998
#         Yes              16048
# Name: HeartDisease, dtype: int64

# %%
sns.countplot(data=heart_for_dup,y='HeartDisease',hue='Sex')

plt.title('Histogram of HeartDisease by Sex')
plt.show()

# %%
sns.countplot(data=heart_for_dup,y='AgeCategory',hue='Sex',order=order_age)

plt.title('Histogram of AgeCategory by Sex')
plt.show()

# %%
sns.countplot(data=heart_for_dup,y='AgeCategory',hue='HeartDisease',order=order_age)

plt.title('Histogram of AgeCategory by HeartDisease')
plt.show()

# %%
heart_for_dup['AlcoholDrinking'].value_counts()
# Out:
# No     280136
# Yes     21581
# Name: AlcoholDrinking, dtype: int64

# %%
heart_for_dup.groupby(['AlcoholDrinking','HeartDisease'])['HeartDisease'].count()
# Out:
# AlcoholDrinking  HeartDisease
# No               No              254016
#                  Yes              26120
# Yes              No               20440
#                  Yes               1141
# Name: HeartDisease, dtype: int64

# %%
heart_for_dup['KidneyDisease'].value_counts()
# Out:
# No     289941
# Yes     11776
# Name: KidneyDisease, dtype: int64

# %%
heart_for_dup.groupby(['KidneyDisease','HeartDisease'])['HeartDisease'].count()
# Out:
# KidneyDisease  HeartDisease
# No             No              266134
#                Yes              23807
# Yes            No                8322
#                Yes               3454
# Name: HeartDisease, dtype: int64

# %%
sns.countplot(data=heart_for_dup,y='KidneyDisease',hue='HeartDisease')

plt.title('Histogram of KidneyDisease by HeartDisease')
plt.show()

# %%
heart_for_dup.groupby(['SkinCancer','HeartDisease'])['HeartDisease'].count()
# Out:
# SkinCancer  HeartDisease
# No          No              250132
#             Yes              22293
# Yes         No               24324
#             Yes               4968
# Name: HeartDisease, dtype: int64

# %%
sns.countplot(data=heart_for_dup,y='SkinCancer',hue='HeartDisease')

plt.title('Histogram of SkinCancer by HeartDisease')
plt.show()

# %%
heart_for_dup.groupby(['SkinCancer','Race'])['Race'].count()
# Out:
# SkinCancer  Race
# No          American Indian/Alaskan Native      5022
#             Asian                               7937
#             Black                              22672
#             Hispanic                           26693
#             Other                              10411
#             White                             199690
# Yes         American Indian/Alaskan Native       170
#             Asian                                 56
#             Black                                138
#             Hispanic                             414
#             Other                                480
#             White                              28034
# Name: Race, dtype: int64

# %%
heart_for_dup.groupby(['Asthma','HeartDisease'])['HeartDisease'].count()
# Out:
# Asthma  HeartDisease
# No      No              236737
#         Yes              22329
# Yes     No               37719
#         Yes               4932
# Name: HeartDisease, dtype: int64

# %%
heart_for_dup.groupby(['Diabetic','HeartDisease'])['HeartDisease'].count()
# Out:
# Diabetic                 HeartDisease
# No                       No              234380
#                          Yes              17416
# No, borderline diabetes  No                5987
#                          Yes                789
# Yes                      No               31641
#                          Yes               8948
# Yes (during pregnancy)   No                2448
#                          Yes                108
# Name: HeartDisease, dtype: int64

# %%
heart_for_dup.Diabetic.value_counts()
# Out:
# No                         251796
# Yes                         40589
# No, borderline diabetes      6776
# Yes (during pregnancy)       2556
# Name: Diabetic, dtype: int64

# %%
heart_for_dup.GenHealth.value_counts()
# Out:
# Very good    104796
# Good          91239
# Excellent     59737
# Fair          34659
# Poor          11286
# Name: GenHealth, dtype: int64

# %%
#check if diabetic=yes, during pregnacy are only female? 
heart_only_peg=heart_for_dup.copy()

# %%
heart_only_peg=(heart_only_peg[heart_only_peg.Diabetic=='Yes (during pregnancy)'])

# %%
heart_only_peg.shape
# Out:
# (2556, 18)

# %%
sns.countplot(data=heart_for_dup,y='AgeCategory',hue='Sex',order=order_age)

plt.title('Histogram of AgeCategory by Sex')
plt.show()

# %%
#Until age of 35, there is more male then female
#most of the data - ages 55-75

# %%
normalize_plot(heart_for_dup,'AgeCategory','Smoking',order_age,4,3)

# %%
#note: this plot represent only the sick people
#it's clear that smokers have more heart disease

# %%
order_GenHealth = ['Poor','Fair','Good','Very good','Excellent']

# generall health - Would you say that in general your health is.. 
#means that feature is subjective!

# %%
normalize_plot(heart_for_dup,'GenHealth','Smoking',order_GenHealth,3,2)

# %%
normalize_plot(heart_for_dup,'GenHealth','HeartDisease',order_GenHealth,3,2)

# %%
normalize_plot(heart_for_dup,'Stroke','HeartDisease',None,3,2)

# %%
normalize_plot(heart_for_dup,'Diabetic','HeartDisease',None,4,2)

# %%
normalize_plot(heart_for_dup,'Asthma','HeartDisease',None,3,2)

# %%
normalize_plot(heart_for_dup,'KidneyDisease','HeartDisease',None,3,2)

# %%
normalize_plot(heart_for_dup,'SkinCancer','HeartDisease',None,3,2)

# %%
normalize_plot(heart_for_dup,'GenHealth','PhysicalActivity',order_GenHealth,3,2)

# %%
# neseccery to change the lables to 'stroke' and 'non-stroke', also change the colors

# %%
sns.boxplot(x='SleepTime', data=heart_for_dup)
# Out:
# <Axes: xlabel='SleepTime'>

# %%
#def graph_with_lines(df,byparam,param1,param2=None):

#    plt.figure(figsize=(8,5))

#    df.groupby(byparam).size().plot(kind='bar')

#    df.groupby(byparam)[param1].mean().plot(kind='line', secondary_y=True, color='b', label=param1)
    
 #   if param2==None:
  #      None
   # else:
    #    df.groupby(byparam)[param2].mean().plot(kind='line', secondary_y=True, color='r', label=param2)

   # plt.title(f'Parameters Average by {byparam}')
   # plt.legend(loc="upper left")

# %%
graph_with_lines(heart_for_dup,'AgeCategory','SleepTime')

plt.xticks(ticks=range(len(order_age)), labels=order_age)
plt.show()

# %%
graph_with_lines(heart_for_dup,'Sex','SleepTime')

# %%
# not sure why we need the line

# %%
graph_with_lines(heart_for_dup,'AgeCategory','PhysicalHealth','MentalHealth')

plt.xticks(ticks=range(len(order_age)), labels=order_age)

plt.show()

# %%
graph_with_lines(heart_for_dup[heart_for_dup.PhysicalActivity =="Yes"],'AgeCategory','PhysicalHealth','MentalHealth')
graph_with_lines(heart_for_dup[heart_for_dup.PhysicalActivity =="No"],'AgeCategory','PhysicalHealth','MentalHealth')
plt.xticks(ticks=range(len(order_age)), labels=order_age)

plt.show()

# %%
#physical -  Now thinking about your physical health, which includes physical illness and injury, 
#           for how many days during the past 30 days was your physical health not good? (0-30 days)


#mental - Thinking about your mental health, 
#         for how many days during the past 30 days was your mental health not good? (0-30 days)

#subjectly, people need to rank the health of themselve in the past 30 days.  
# 0 - no illness or injury

#first, ckeck that two features without plot. next, chagne the plot. one plot for phycal and anther for mantal by ages
# and heart disease.

# %%
#
heart_for_dup.groupby(['PhysicalHealth']).size()
# Out:
# PhysicalHealth
# 0.0     208611
# 1.0      10459
# 2.0      14846
# 3.0       8608
# 4.0       4467
# 5.0       7590
# 6.0       1270
# 7.0       4629
# 8.0        924
# 9.0        180
# 10.0      5450
# 11.0        85
# 12.0       605
# 13.0        91
# 14.0      2892
# 15.0      5012
# 16.0       135
# 17.0       110
# 18.0       167
# 19.0        35
# 20.0      3216
# 21.0       626
# 22.0        89
# 23.0        46
# 24.0        67
# 25.0      1164
# 26.0        66
# 27.0       124
# 28.0       446
# 29.0       204
# 30.0     19503
# dtype: int64

# %%
heart_for_dup.groupby(['MentalHealth']).size()
# Out:
# MentalHealth
# 0.0     187898
# 1.0       9235
# 2.0      16309
# 3.0      10412
# 4.0       5364
# 5.0      14004
# 6.0       1510
# 7.0       5516
# 8.0       1094
# 9.0        203
# 10.0     10459
# 11.0        83
# 12.0       757
# 13.0       110
# 14.0      2048
# 15.0      9871
# 16.0       152
# 17.0       128
# 18.0       211
# 19.0        21
# 20.0      5426
# 21.0       352
# 22.0        98
# 23.0        68
# 24.0        67
# 25.0      1953
# 26.0        59
# 27.0       126
# 28.0       515
# 29.0       317
# 30.0     17351
# dtype: int64

# %%
#show only sick peole
heartdf_yes=(heart_for_dup[heart_for_dup.HeartDisease=='Yes'])

# %%
heartdf_yes.groupby(['PhysicalHealth']).size()
# Out:
# PhysicalHealth
# 0.0     14310
# 1.0       605
# 2.0      1169
# 3.0       843
# 4.0       494
# 5.0       896
# 6.0       173
# 7.0       465
# 8.0       120
# 9.0        37
# 10.0      838
# 11.0        9
# 12.0      104
# 13.0       10
# 14.0      312
# 15.0      930
# 16.0       21
# 17.0       21
# 18.0       33
# 19.0        9
# 20.0      641
# 21.0       99
# 22.0       15
# 23.0       12
# 24.0       15
# 25.0      254
# 26.0       12
# 27.0       28
# 28.0      108
# 29.0       59
# 30.0     4619
# dtype: int64

# %%
heartdf_yes.groupby(['MentalHealth']).size()
# Out:
# MentalHealth
# 0.0     18103
# 1.0       613
# 2.0      1041
# 3.0       658
# 4.0       323
# 5.0       882
# 6.0       112
# 7.0       318
# 8.0        71
# 9.0        19
# 10.0      805
# 11.0       11
# 12.0       60
# 13.0        7
# 14.0      147
# 15.0      907
# 16.0       15
# 17.0       11
# 18.0       16
# 19.0        2
# 20.0      483
# 21.0       42
# 22.0        9
# 23.0        5
# 24.0        8
# 25.0      198
# 26.0        4
# 27.0        9
# 28.0       56
# 29.0       39
# 30.0     2287
# dtype: int64

# %%
heartdf_yes.groupby(['Race']).size()
# Out:
# Race
# American Indian/Alaskan Native      542
# Asian                               266
# Black                              1729
# Hispanic                           1443
# Other                               886
# White                             22395
# dtype: int64

# %%
graph_with_lines(heart_for_dup,'Race','PhysicalHealth','MentalHealth')

# %%
graph_with_lines(heart_for_dup,'GenHealth','PhysicalHealth','MentalHealth')
plt.xticks(ticks=range(len(order_GenHealth)), labels=order_GenHealth)

plt.show()

# %%
graph_with_lines(heart_for_dup,'AgeCategory','BMI')

plt.xticks(ticks=range(len(order_age)), labels=order_age)
plt.show()

# %%
graph_with_lines(heart_for_dup,'Race','BMI')

# %%
graph_with_lines(heart_for_dup,'Diabetic','BMI')

# %%
graph_with_lines(heart_for_dup,'DiffWalking','BMI')

# %%
#corraltion matrix

plt.figure(figsize=(4,4))
sns.heatmap(heart_for_dup.corr(),cbar=True,annot=True,cmap='Blues')
plt.title('Correlation matrix')
plt.show()

# %%
#sns.pairplot(heartdf)

# %%
# sns.pairplot(heart_for_dup,hue='HeartDisease')
# plt.legend('HeartDisease')

# %%
heart_for_dup.groupby(['HeartDisease']).size()
# Out:
# HeartDisease
# No     274456
# Yes     27261
# dtype: int64

# %%
col_to_index = ['Smoking','AlcoholDrinking','Stroke','DiffWalking','Sex',
                                'Race','Diabetic','GenHealth',
                                'PhysicalActivity','Asthma','KidneyDisease','SkinCancer']

list_col = ['AgeCategory']

age_dict = {'18-24':18,'25-29':25,'30-34':30,'35-39':35,'40-44':40,'45-49':45,'50-54':50,'55-59':55,'60-64':60,
            '65-69':65,'70-74':70,'75-79':75,'80 or older':80}
list_dict = [age_dict]

# %%
X=heart_for_dup.drop('HeartDisease',axis=1)
y=heart_for_dup['HeartDisease'].replace({"Yes":1,"No":0})

X_train, X_test, y_train, y_test = split(X, y, test_size=0.3, 
                                            random_state=951357)

# %%
pipe1 = Pipeline([
    ("columnAdd",AddColumnIndex(col_to_index)),
    ("columnDropper",AddColumnGroup(list_col,list_dict)),
    ('LR',LogisticRegression(class_weight="balanced"))
])

pipe2 = Pipeline([
    ("columnAdd",AddColumnIndex(col_to_index)),
    ("columnDropper",AddColumnGroup(list_col,list_dict)),
    ('LR',LogisticRegression(class_weight={1:10,0:1}))
])


pipe3 = Pipeline([
    ("columnAdd",AddColumnIndex(col_to_index)),
    ("columnDropper",AddColumnGroup(list_col,list_dict)),
    ('LR',LogisticRegression(class_weight={1:5,0:0.5}))
])

pipe4 = Pipeline([
    ("columnAdd",AddColumnIndex(col_to_index)),
    ("columnDropper",AddColumnGroup(list_col,list_dict))
])

pipe5 = Pipeline([
    ("columnAdd",AddColumnIndex(col_to_index)),
    ("columnDropper",AddColumnGroup(list_col,list_dict)),
    ("RF",RandomForestClassifier(class_weight="balanced"))
])

# %%
model1 = pipe1.fit(X_train,y_train)
model2 = pipe2.fit(X_train,y_train)
model3 = pipe3.fit(X_train,y_train)

# %%
X_train
# Out:
#           BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  MentalHealth  \
# 87947   48.78     Yes              No     No             0.0           1.0
# 280538  24.94      No              No    Yes             7.0           0.0
# 25547   32.98      No              No     No             0.0           0.0
# 13024   28.70     Yes              No     No            30.0          15.0
# 201214  34.96     Yes              No     No             0.0           0.0
# ...       ...     ...             ...    ...             ...           ...
# 126901  23.33     Yes              No     No             0.0          10.0
# 94584   34.95      No              No     No             0.0           0.0
# 102774  20.22      No              No     No             0.0           0.0
# 317558  20.80      No              No     No             5.0           0.0
# 214946  29.68      No              No     No             4.0          25.0
#
#        DiffWalking     Sex AgeCategory      Race Diabetic PhysicalActivity  \
# 87947           No    Male       40-44     White       No              Yes
# 280538         Yes  Female       55-59     White       No               No
# 25547           No    Male       35-39     White       No               No
# 13024          Yes    Male       70-74     White      Yes               No
# 201214          No    Male       55-59     White      Yes              Yes
# ...            ...     ...         ...       ...      ...              ...
# 126901          No    Male       40-44     White       No              Yes
# 94584           No  Female       45-49     White       No              Yes
# 102774          No  Female       55-59     White       No               No
# 317558          No  Female       50-54  Hispanic       No              Yes
# 214946          No    Male       50-54     White       No              Yes
#
#         GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 87947        Good        6.0     No            No         No
# 280538       Fair       10.0     No            No         No
# 25547   Excellent        6.0     No            No         No
# 13024        Poor        6.0     No            No         No
# 201214  Very good        7.0     No            No         No
# ...           ...        ...    ...           ...        ...
# 126901  Very good        8.0     No            No         No
# 94584        Good        6.0     No            No         No
# 102774  Excellent        8.0     No            No         No
# 317558  Very good        7.0     No            No         No
# 214946  Very good        5.0     No            No         No
#
# [211201 rows x 17 columns]

# %%
# param_range = [3, 4, 9]
# param_range2 = [2, 3, 5]
# n_estimators = [30,40]

# parameters_XGB = [{'XGB__max_depth': param_range,
#                     'XGB__min_child_weight': param_range2,
#                     'XGB__n_estimators': n_estimators}]
# model5 = GridSearchCV(estimator=pipe4,
#         param_grid=parameters_XGB,
#         cv=3)
# model5.fit(X_train,y_train)

from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(
    class_weight='balanced',
    y=y_train
)
xgb = XGBClassifier(max_depth=4, min_child_weight=2, n_estimators=40)

model5 = xgb.fit(pipe4.fit(X_train),y_train, sample_weight=classes_weights)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 20
#      14 classes_weights = class_weight.compute_sample_weight(
#      15     class_weight='balanced',
#      16     y=y_train
#      17 )
#      18 xgb = XGBClassifier(max_depth=4, min_child_weight=2, n_estimators=40)
# ---> 20 model5 = xgb.fit(pipe4.fit(X_train),y_train, sample_weight=classes_weights)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:1471, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1460     params["num_class"] = self.n_classes_
#    1462 (
#    1463     model,
#    1464     metric,
#    (...)
#    1469     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1470 )
# -> 1471 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1472     missing=self.missing,
#    1473     X=X,
#    1474     y=y,
#    1475     group=None,
#    1476     qid=None,
#    1477     sample_weight=sample_weight,
#    1478     base_margin=base_margin,
#    1479     feature_weights=feature_weights,
#    1480     eval_set=eval_set,
#    1481     sample_weight_eval_set=sample_weight_eval_set,
#    1482     base_margin_eval_set=base_margin_eval_set,
#    1483     eval_group=None,
#    1484     eval_qid=None,
#    1485     create_dmatrix=self._create_dmatrix,
#    1486     enable_categorical=self.enable_categorical,
#    1487     feature_types=self.feature_types,
#    1488 )
#    1490 self._Booster = train(
#    1491     params,
#    1492     train_dmatrix,
#    (...)
#    1501     callbacks=callbacks,
#    1502 )
#    1504 if not callable(self.objective):
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:448, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     428 def _wrap_evaluation_matrices(
#     429     missing: float,
#     430     X: Any,
#    (...)
#     444     feature_types: Optional[FeatureTypes],
#     445 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     446     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     447     way."""
# --> 448     train_dmatrix = create_dmatrix(
#     449         data=X,
#     450         label=y,
#     451         group=group,
#     452         qid=qid,
#     453         weight=sample_weight,
#     454         base_margin=base_margin,
#     455         feature_weights=feature_weights,
#     456         missing=missing,
#     457         enable_categorical=enable_categorical,
#     458         feature_types=feature_types,
#     459         ref=None,
#     460     )
#     462     n_validation = 0 if eval_set is None else len(eval_set)
#     464     def validate_or_none(meta: Optional[Sequence], name: str) -> Sequence:
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\sklearn.py:908, in XGBModel._create_dmatrix(self, ref, **kwargs)
#     906     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#     907         pass
# --> 908 return DMatrix(**kwargs, nthread=self.n_jobs)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\core.py:743, in DMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical)
#     740     assert self.handle is not None
#     741     return
# --> 743 handle, feature_names, feature_types = dispatch_data_backend(
#     744     data,
#     745     missing=self.missing,
#     746     threads=self.nthread,
#     747     feature_names=feature_names,
#     748     feature_types=feature_types,
#     749     enable_categorical=enable_categorical,
#     750 )
#     751 assert handle is not None
#     752 self.handle = handle
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\xgboost\data.py:1013, in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#    1010 if converted is not None:
#    1011     return _from_scipy_csr(converted, missing, threads, feature_names, feature_types)
# -> 1013 raise TypeError('Not supported type for data.' + str(type(data)))
#
# TypeError: Not supported type for data.<class 'sklearn.pipeline.Pipeline'>

# %%
parameters_RF = [{'RF__min_samples_leaf': param_range2,
                   'RF__max_depth': param_range,
                    'RF__n_estimators': n_estimators}]
model6 = GridSearchCV(estimator=pipe5,
        param_grid=parameters_RF,
        cv=3)
model6.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('columnAdd',
#                                         <pipeline.AddColumnIndex object at 0x0000019B857FDAD0>),
#                                        ('columnDropper',
#                                         <pipeline.AddColumnGroup object at 0x0000019B857FF910>),
#                                        ('RF',
#                                         RandomForestClassifier(class_weight='balanced'))]),
#              param_grid=[{'RF__max_depth': [3, 4, 9],
#                           'RF__min_samples_leaf': [2, 3, 5],
#                           'RF__n_estimators': [30, 40]}])

# %%
print(report(model1, X_train, y_train))
# Out:
# accuracy: 0.738
#
#         0      1
# 0  141755  50417
# 1    4826  14203
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.74      0.84    192172
#            1       0.22      0.75      0.34     19029
#
#     accuracy                           0.74    211201
#    macro avg       0.59      0.74      0.59    211201
# weighted avg       0.90      0.74      0.79    211201

# %%
print(report(model2, X_train, y_train))
# Out:
# accuracy: 0.729
#
#         0      1
# 0  139815  52357
# 1    4810  14219
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83    192172
#            1       0.21      0.75      0.33     19029
#
#     accuracy                           0.73    211201
#    macro avg       0.59      0.74      0.58    211201
# weighted avg       0.90      0.73      0.79    211201

# %%
print(report(model3, X_train, y_train))
# Out:
# accuracy: 0.732
#
#         0      1
# 0  140316  51856
# 1    4711  14318
#
#               precision    recall  f1-score   support
#
#            0       0.97      0.73      0.83    192172
#            1       0.22      0.75      0.34     19029
#
#     accuracy                           0.73    211201
#    macro avg       0.59      0.74      0.58    211201
# weighted avg       0.90      0.73      0.79    211201

# %%
print(report(model4, X_train, y_train))
print(report(model4, X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:111, in _check_targets(y_true, y_pred)
#     110 try:
# --> 111     unique_values = np.union1d(y_true, y_pred)
#     112 except TypeError as e:
#     113     # We expect y_true and y_pred to be of the same data type.
#     114     # If `y_true` was provided to the classifier as strings,
#     115     # `y_pred` given by the classifier will also be encoded with
#     116     # strings. So we raise a meaningful error
#
# File <__array_function__ internals>:200, in union1d(*args, **kwargs)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:932, in union1d(ar1, ar2)
#     900 """
#     901 Find the union of two arrays.
#     902
#    (...)
#     930 array([1, 2, 3, 4, 6])
#     931 """
# --> 932 return unique(np.concatenate((ar1, ar2), axis=None))
#
# File <__array_function__ internals>:200, in unique(*args, **kwargs)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:274, in unique(ar, return_index, return_inverse, return_counts, axis, equal_nan)
#     273 if axis is None:
# --> 274     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#     275                     equal_nan=equal_nan)
#     276     return _unpack_tuple(ret)
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\lib\arraysetops.py:336, in _unique1d(ar, return_index, return_inverse, return_counts, equal_nan)
#     335 else:
# --> 336     ar.sort()
#     337     aux = ar
#
# TypeError: '<' not supported between instances of 'str' and 'int'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 print(report(model4, X_train, y_train))
#       2 print(report(model4, X_test, y_test))
#
# File c:\Users\Renato\Documents\GitHub\Final-Project---Heart-diseases\functions.py:68, in report(clf, X, y)
#      67 def report(clf, X, y):
# ---> 68     acc = accuracy_score(y_true=y,
#      69                          y_pred=clf.predict(X))
#      70     cm = pd.DataFrame(confusion_matrix(y_true=y,
#      71                                        y_pred=clf.predict(X)),
#      72                       index=clf.classes_,
#      73                       columns=clf.classes_)
#      74     rep = classification_report(y_true=y,
#      75                                 y_pred=clf.predict(X))
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:220, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     154 """Accuracy classification score.
#     155
#     156 In multilabel classification, this function computes subset accuracy:
#    (...)
#     216 0.5
#     217 """
#     219 # Compute accuracy for each possible representation
# --> 220 y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     221 check_consistent_length(y_true, y_pred, sample_weight)
#     222 if y_type.startswith("multilabel"):
#
# File c:\Users\Renato\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:117, in _check_targets(y_true, y_pred)
#     111     unique_values = np.union1d(y_true, y_pred)
#     112 except TypeError as e:
#     113     # We expect y_true and y_pred to be of the same data type.
#     114     # If `y_true` was provided to the classifier as strings,
#     115     # `y_pred` given by the classifier will also be encoded with
#     116     # strings. So we raise a meaningful error
# --> 117     raise TypeError(
#     118         "Labels in y_true and y_pred should be of the same type. "
#     119         f"Got y_true={np.unique(y_true)} and "
#     120         f"y_pred={np.unique(y_pred)}. Make sure that the "
#     121         "predictions provided by the classifier coincides with "
#     122         "the true labels."
#     123     ) from e
#     124 if len(unique_values) > 2:
#     125     y_type = "multiclass"
#
# TypeError: Labels in y_true and y_pred should be of the same type. Got y_true=[0 1] and y_pred=['No' 'Yes']. Make sure that the predictions provided by the classifier coincides with the true labels.

# %%
print(report(model5, X_train, y_train))
# Out:
# accuracy: 0.687
#
#          No    Yes
# No   129700  62472
# Yes    3718  15311
#
#               precision    recall  f1-score   support
#
#           No       0.97      0.67      0.80    192172
#          Yes       0.20      0.80      0.32     19029
#
#     accuracy                           0.69    211201
#    macro avg       0.58      0.74      0.56    211201
# weighted avg       0.90      0.69      0.75    211201

# %%
print(report(model6, X_train, y_train))
print(report(model6, X_test, y_test))
# Out:
# accuracy: 0.725
#
#          No    Yes
# No   137581  54591
# Yes    3503  15526
#
#               precision    recall  f1-score   support
#
#           No       0.98      0.72      0.83    192172
#          Yes       0.22      0.82      0.35     19029
#
#     accuracy                           0.72    211201
#    macro avg       0.60      0.77      0.59    211201
# weighted avg       0.91      0.72      0.78    211201
#
# accuracy: 0.722
#
#         No    Yes
# No   58838  23446
# Yes   1684   6548
#
#               precision    recall  f1-score   support
#
#           No       0.97      0.72      0.82     82284
#          Yes       0.22      0.80      0.34      8232
#
#     accuracy                           0.72     90516
#    macro avg       0.60      0.76      0.58     90516
# weighted avg       0.90      0.72      0.78     90516
